# %%
textx = """$$Mỉm cười rạng rỡ, vẫy tay chào$$ "Chào bạn! Mình Hana đây! Tớ vui quá khi được gặp bạn! $$Nháy mắt lấp lánh$$ Bạn khỏe không?"""

import tools.tools as tools
text = tools.format_discord_message(textx)

# %%
print(text)
# Out:
# _ Mỉm cười rạng rỡ, vẫy tay chào _
# **Chào bạn! Mình Hana đây! Tớ vui quá khi được gặp bạn!**
# _ Nháy mắt lấp lánh _
# **Bạn khỏe không?**

# %%
import subprocess

command = [
    ".\\llamacpp\\llama-cli.exe",
    "-m", "weights\\Gemma3\\gemma-3-4B-it-QAT-Q4_0.gguf",
    "--mmproj", "weights\\Gemma3\\mmproj-model-f16.gguf",
    "-p", "OCR",
    "--image", "downloads\\image_20250425_200251_547265_1365312100439691264.png",
]

result = subprocess.run(command, capture_output=True, text=True)

print("Output:")
print(result.stdout)

if result.stderr:
    print("Error:")
    print(result.stderr)
# Out:
# Output:
